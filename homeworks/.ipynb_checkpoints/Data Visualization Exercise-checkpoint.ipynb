# %% [markdown]
# # Getting the (wrong) picture from the data
# ## Foot length and spelling/grammatical errors

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
data = read.csv('fs.csv')

# %%
data
# Out:
#    ft_size num_mistakes
# 1  17.5    15
# 2  17.5    18
# 3  17.5    19
# 4  17.5    20
# 5  18.0    16
# 6  18.0    17
# 7  18.0    18
# 8  18.0    19
# 9  18.5    14
# 10 18.5    16
# 11 18.5    17
# 12 19.0    15
# 13 19.0    16
# 14 20.0    13
# 15 20.0    14
# 16 20.0    15
# 17 20.5    12
# 18 20.5    13
# 19 20.5    14
# 20 20.5    15
# 21 21.0    10
# 22 21.0    11
# 23 21.0    13
# 24 21.0    15
# 25 21.5    10
# 26 21.5    12
# 27 21.5    13
# 28 22.0     8
# 29 22.0    10
# 30 22.0    11
# ⋮  ⋮       ⋮
# 42 24.5     6
# 43 24.5     7
# 44 24.5     8
# 45 24.5    10
# 46 25.0     4
# 47 25.0     6
# 48 25.0     7
# 49 25.0     8
# 50 25.5     5
# 51 25.5     6
# 52 26.0     4
# 53 26.0     5
# 54 26.0     7
# 55 26.5     3
# 56 26.5     4
# 57 26.5     5
# 58 27.0     2
# 59 27.0     3
# 60 27.0     4
# 61 27.0     7
# 62 27.5     2
# 63 27.5     3
# 64 28.0     0
# 65 28.0     1
# 66 28.0     2
# 67 28.0     4
# 68 28.5     0
# 69 28.5     2
# 70 29.0     0
# ...

# %%
# ggplot(data, xlab = 'feet size (cm)', ylab = 'number of mistakes')
ggplot(data=data, aes(x=ft_size, y=num_mistakes)) +geom_point()
# Out:
# plot without title

# %% [markdown]
# ## Synthesis

# %% [markdown]
# There appears to be a correlation between the number of mistakes made and the feet size. Perhaps feet size has an indirect correlation with feet size and this implies that the performance is correlated with age.
